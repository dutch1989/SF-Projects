# %% [markdown]
# # Проект - 3. Задача классификации

# %% [markdown]
# *   Бизнес-задача: определить характеристики, по которым можно выявить клиентов, более склонных к открытию депозита в банке, и за счёт этого повысить результативность маркетинговой кампании.
#
# *   Техническая задача для вас как для специалиста в Data Science: построить модель машинного обучения, которая на основе предложенных характеристик клиента будет предсказывать, воспользуется он предложением об открытии депозита или нет.

# %%
#!pip install Optuna

# %%
# импортируем необходимые библиотеки 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing  import LabelEncoder
from sklearn import linear_model 
from sklearn import tree 
from sklearn import ensemble 
from sklearn import metrics 
from sklearn import preprocessing 
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.model_selection import GridSearchCV
import optuna
from sklearn.neighbors import LocalOutlierFactor

# %%
# Сохраним среду выполнения 
# !pip freeze > requirements.txt

# %% [markdown]
# ## Часть 1. Знакомство с данными, обработка пропусков и выбросов

# %% [markdown]
#  Прочитаем наши данные, выведем информацию о столбцах, и их содержании.

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Project-4/bank_fin.csv', sep = ';')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  object
#  3   education  11162 non-null  object
#  4   default    11162 non-null  object
#  5   balance    11137 non-null  object
#  6   housing    11162 non-null  object
#  7   loan       11162 non-null  object
#  8   contact    11162 non-null  object
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  object
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11162 non-null  object
# dtypes: int64(6), object(11)
# memory usage: 1.4+ MB

# %% [markdown]
# ---
# как мы видим у нас 17 столбцов и 11162 строки, 6 числовых, 11 текстовых

# %%
# Проверим наши данные на наличие пропусков
df.isna().sum()
# Out:
# age           0
# job           0
# marital       0
# education     0
# default       0
# balance      25
# housing       0
# loan          0
# contact       0
# day           0
# month         0
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# deposit       0
# dtype: int64

# %% [markdown]
# ---
# В столбце баланса имеются пропуски значений

# %% [markdown]
# ### Пропуски в данных

# %% [markdown]
# Для начала преобразуем признак 'balance' из текстового(object) в числовой(float) убрав знак $

# %%
df['balance'] = df['balance'].apply(lambda x: float(x.replace(' ','').replace(',','.')[:-1]) if x is not np.nan else x)
df['balance']
# Out:
# 0        2343.0
# 1          45.0
# 2        1270.0
# 3        2476.0
# 4         184.0
#           ...
# 11157       1.0
# 11158     733.0
# 11159      29.0
# 11160       0.0
# 11161       0.0
# Name: balance, Length: 11162, dtype: float64

# %%
# Заполним пропуски в столбце медианным значением
df['balance'] = df['balance'].fillna(df['balance'].median())

# %% [markdown]
# ### Неявные пропуски данных

# %%
# У признаков education и job имеются неявные пропуски значений и обозначены как 'unknown'
df['job'].value_counts(), df['education'].value_counts()
# Out:
# (management       2566
#  blue-collar      1944
#  technician       1823
#  admin.           1334
#  services          923
#  retired           778
#  self-employed     405
#  student           360
#  unemployed        357
#  entrepreneur      328
#  housemaid         274
#  unknown            70
#  Name: job, dtype: int64, secondary    5476
#  tertiary     3689
#  primary      1500
#  unknown       497
#  Name: education, dtype: int64)

# %% [markdown]
# ---
# Уберем пропуски заменив их модальными значениями

# %%
df['job'] = df['job'].apply(lambda x: df['job'].mode()[0] if x == 'unknown' else x)
df['education'] = df['education'].apply(lambda x: df['education'].mode()[0] if x == 'unknown' else x)

# %% [markdown]
# ### Выбросы

# %% [markdown]
# Для удаления выбросов применим алгоритм LocalOutlierFactor, который принимает решение о признания объекта выбросом на основе его ближайших соседей

# %%
x = df.copy()
# для начала преобразуем текстовые признаки в числовые

# создадим список из порядковых признаков и применим к ним LabelEncoder
columns_for_transform = ['education','default','housing','loan','deposit'] 
le = LabelEncoder()
for feature in columns_for_transform:
  x[feature] = le.fit_transform(x[feature])

# остальные закодируем Onehot кодированием
x = pd.get_dummies(x)

#Обучим наш алгоритм и обнаружим наши пропуски
lof = LocalOutlierFactor()
out_pred = lof.fit_predict(x)

# Отфильтруем наши данные и удалим выбросы 
mask = out_pred != -1
df = df[mask]

# %% [markdown]
# ## Часть 2:  Разведывательный анализ

# %% [markdown]
# ### Сбалансированность классов

# %%
# изучим соотношение классов нашей целевой переменной на предмет несбалансированности
print('Клиентов не открывших депозит: {}'.format(df['deposit'].value_counts()[0]))
print('Клиентов открывших депозит: {}'.format(df['deposit'].value_counts()[1]))
print('---------------------------------------------')
plt.figure(figsize=(4,5))
fig = sns.countplot(df['deposit'])
fig.set_title('Количество клиентов открывших и не открывших депозит');
# Out:
# Клиентов не открывших депозит: 5774
# Клиентов открывших депозит: 5119
# ---------------------------------------------

# %% [markdown]
# ---
# Как мы видим среди данных есть незначительный перевес клиентов неоткрывших депозит в банке, который необходимо учесть в дальнейшем

# %% [markdown]
# ### Описательные статистики для количественных переменных

# %%
# Взглянем на количественные переменные в данных 
# и определим меры центральной тенденции, минимумы/максимумы значений
columns_for_visual = df.select_dtypes(exclude='object').columns
df[columns_for_visual].describe().T
# Out:
#             count         mean          std     min    25%    50%     75%  \
# age       10893.0    41.181034    11.844874    18.0   32.0   39.0    49.0
# balance   10893.0  1480.025429  2690.882998 -1206.0  130.0  556.0  1704.0
# day       10893.0    15.660149     8.419118     1.0    8.0   15.0    22.0
# duration  10893.0   363.183604   325.712982     2.0  138.0  252.0   485.0
# campaign  10893.0     2.504177     2.668849     1.0    1.0    2.0     3.0
# pdays     10893.0    48.495915   102.360461    -1.0   -1.0   -1.0    -1.0
# previous  10893.0     0.802075     2.188955     0.0    0.0    0.0     0.0
#
#               max
# age          95.0
# balance   32685.0
# day          31.0
# duration   2330.0
# campaign     63.0
# pdays       774.0
# previous     58.0

# %% [markdown]
# ---
# Как мы видим возраст клиентов банка варьируется от 18 до 95 лет, средний возраст около 40 лет.
# Баланс счета от отрицательного до 32 тыс. долларов, средний баланс по счетам составляет около 2500 тысяч.

# %%
# Визуализируем наши данные построим их распределение и межквартильный размах 
for n in columns_for_visual:
  fig,axes = plt.subplots(2,1,figsize=(8,6))
  axes[0].hist(df[n],bins=25)
  axes[0].set_xlabel(n)
  axes[0].set_ylabel('Count')
  axes[0].set_title(f'Распределение {n}')
  sns.boxplot(x=df[n],ax=axes[1])
fig.show()

# %% [markdown]
# ### Описательные статистики для категориальных переменных

# %%
# Рассмотрим категориальные переменные в данных
categorial_columns = df.select_dtypes(include='object').columns
df[categorial_columns].describe().T
# Out:
#            count unique         top   freq
# job        10893     11  management   2569
# marital    10893      3     married   6196
# education  10893      3   secondary   5837
# default    10893      2          no  10732
# housing    10893      2          no   5763
# loan       10893      2          no   9486
# contact    10893      3    cellular   7842
# month      10893     12         may   2759
# poutcome   10893      4     unknown   8214
# deposit    10893      2          no   5774

# %% [markdown]
# ---
# Из данных следует:
# *   Среди клиентов четверть работают в сфере менеджмента
# *   больше половины женаты/замужем
# *   половина клиентов имеет среднее образование
# *   почти все клиенты не имеют просроченый кредит
# *   около половины клиентов имеют кредит на жилье
# *   почти никто не имеет кредит на наличные нужды
# *   большиство было привлечено посредством телефонного разговора

# %%
# Визуализируем данные 
for n in categorial_columns:
  fig,axes = plt.subplots(figsize=(5,5))
  plt.pie(x=df[n].value_counts(sort=False),labels=df[n].unique(),autopct='%.1f%%')
  axes.set_title(f'Разделение на пропорции признака: {n}')
  fig.show()

# %% [markdown]
# Посмотрим как влияет участие в предыдущей маркетинговой компании на решение в текущей. Построим стобчатые диаграммы:

# %%
plt.figure(figsize=(9,6))
fig = sns.countplot(x=df['poutcome'],hue=df['deposit'],palette='husl')
fig.set_title('Лояльность клиента в зависимости от участия в предыдущей маркетинговой компании')
fig.set_xlabel('Статус участия в предыдущей компании');
fig.legend(labels=['открыл депозит в текущей компании','не открыл депозит в текущей компании']);

# %% [markdown]
# ---
# Как мы видим большинство клиентов, которые поучавствовали в предыдущей маркетинговой компании открыли депозит в текущей компании

# %%
# узнаем в каком месяце процент отказов от предложения был наибольшим

percentage_of_failures = dict()

for month in df['month'].unique():
# вычислим общее количество клиентов
  count_of_failures = df[(df['month']==month) & (df['deposit']=='no')]['month'].count()
# и клиентов отказавшихся от открытия депозита
  count_of_month = df[df['month']==month]['month'].count()
# посчитаем процент по каждому месяцу и добавим значения в словарь
  percent_of_fail_per_month = (count_of_failures / count_of_month) * 100
  percentage_of_failures[month] = round(percent_of_fail_per_month, 2)

print('Процент отказов от предложения по месяцам:')
print(sorted(percentage_of_failures.items(),key=lambda x: x[1],reverse=True))
# Out:
# Процент отказов от предложения по месяцам:
# [('may', 67.71), ('jan', 59.46), ('jul', 59.1), ('nov', 57.65), ('jun', 56.0), ('aug', 55.0), ('feb', 43.36), ('apr', 37.82), ('oct', 16.58), ('sep', 14.9), ('mar', 10.29), ('dec', 9.17)]

# %% [markdown]
# ---
# Как мы видим май и январь и июль лидируют по отказам в процентном соотношении, возможно это связано с периодом отпусков

# %%
# посмотрим какие возрастные группы более склонны открывать депозит в банке

age = dict()
# создадим маски с возрастными группами (до 30, 30-40, 40-50, 50-60 и 60+ лет)
mask_less_30 = df['age']<30
mask_between_30_40 = df['age'].between(30,40,inclusive='left')
mask_between_40_50 = df['age'].between(40,50,inclusive='left')
mask_between_50_60 = df['age'].between(40,50,inclusive='left')
mask_more_60 = df['age']>60
# созадим маску на тех кто согласился на предложение банка
success = df['deposit']=='yes'
# посчитаем проценты по возрастным группам и добавим их в словарь
age['<30'] = df[ mask_less_30 & success]['deposit'].count() / df[mask_less_30]['deposit'].count() * 100
age['30-40'] = df[mask_between_30_40 & success]['deposit'].count() / df[mask_between_30_40]['deposit'].count() * 100
age['40-50'] = df[mask_between_40_50 & success]['deposit'].count() / df[mask_between_40_50]['deposit'].count() * 100
age['50-60'] = df[mask_between_50_60 & success]['deposit'].count() / df[mask_between_50_60]['deposit'].count() * 100
age['>60'] = df[mask_more_60 & success]['deposit'].count() / df[mask_more_60]['deposit'].count() * 100

# %% [markdown]
# Визуализируем полученные данные:

# %%
names = list(age.keys())
values = list(age.values())
plt.figure(figsize=(8,7))
fig = sns.barplot(names,values,palette='flare');
fig.set_title('Процент людей открывших депозит/общее количество людей в возрастной группе')
fig.set_xlabel('Возрастные категории')
fig.set_ylabel('%');

# %% [markdown]
# ---
# Как мы видим больше всего склонны принимать предложения люди до 30 лет, а также старше 60.
# Если посмотреть на распределение признака возраста это самые малочисленные группы. Самые большие по численности возрастные группы реже принимают предложение банка

# %%
#  взглянем на численность групп людей открывших/неоткрывших депозит
# в зивисимости от семейного статуса, образования и сферы деятельности

columns_for_visual = ['marital','education','job']
for feature in columns_for_visual:
  plt.subplots(figsize=(8,6))
  fig = sns.countplot(df[feature],hue=df['deposit'],palette='Set2')
  fig.set_xticklabels(fig.get_xticklabels(), rotation=45, horizontalalignment='right')
  fig.set_title(f'Открывшие/неоткрывшие депозит в зависимости от {feature}')

# %% [markdown]
# ---
# Из графиков видно:
#
#
# *   Клиенты без пары более склонны открывать депозит из всех групп, однако самая многочисленная группа(те кто женат/замужем) склонна отказываться от предложения банка
# *   люди с высшим образованием чаще соглашаются на предложение, однако самая крупная группа людей со средним образованием чаще отказывается чем соглашается на открытие депозита
# *  чаще всех принимают предложения студенты, и люди работающие занимающие управляющие должности(это видно из возрастных групп, которые чаще других принимают предложение). Самое большое количество отказов в зависимости от принятия предложения у группы людей заминающихся физическим трудом.

# %%
# Построим тепловую карту для групп людей в зависимости от образвания и 
# семейного положения, которые приняли и отказались от предложения банка

# разобьем выборку на группы:
grouped_1 = df[df['deposit'] =='yes'][['deposit','education','marital']]
grouped_2 = df[df['deposit'] =='no'][['deposit','education','marital']]
# создадим сводные таблицы из групп
pivot_1 = pd.pivot_table(grouped_1,values='deposit',index='marital',columns='education',aggfunc='count')
pivot_2 = pd.pivot_table(grouped_2,values='deposit',index='marital',columns='education',aggfunc='count')
# построим тепловые карты
fig,axes = plt.subplots(2,1,figsize=(6,12))
sns.heatmap(pivot_1,ax=axes[0],annot=True,fmt='.1f');
axes[0].set_title('Количество людей открывших депозит в зависимости от семейного положения и образования')
axes[0].set_xlabel('Образование')
axes[0].set_ylabel('Семейное положение')
sns.heatmap(pivot_2,ax=axes[1],annot=True,fmt='.1f');
axes[1].set_title('Количество людей не открывших депозит в зависимости от семейного положения и образования')
axes[1].set_xlabel('Образование')
axes[1].set_ylabel('Семейное положение');

# %% [markdown]
# Из изображений видно:
# больше всех открывают депозит и отказываются люди женатые/за мужем со средним образованием. (самая большая группа из распределения)
# На втором месте по согласию и отказу одинокие люди со среднем образованием.

# %% [markdown]
# ## Часть 3: Преобразование данных

# %%
# Закодируем признаки порядковым кодированием
columns_for_transform = ['education','default','housing','loan','deposit']
le = LabelEncoder()
for feature in columns_for_transform:
  df[feature] = le.fit_transform(df[feature])

# %%
# преобразуем признак возраста на возрастные группы, которые ранее рассматривали
def age_category(digit):
  if digit < 30:
    return 0
  elif digit in range(30,40):
    return 1
  elif digit in range(40,50):
    return 2
  elif digit in range(50,60):
    return 3
  elif digit >= 60: 
    return 4
# применим функцию к столбцу
df['age'] = df['age'].apply(age_category)

# %%
# остальные категориальные признаки закодируем onehot кодированием
df = pd.get_dummies(df)

# %% [markdown]
# Построим корреляционную матрицу, и посмотрим на наличие мультикорреляции среди признаков

# %%
plt.figure(figsize=(25,25))
sns.heatmap(df.corr(),annot=True,fmt='.2f');

# %% [markdown]
# ---
# Построим столбчатую диаграмму, показывающую корреляцию признаков с целевой переменной

# %%
corr = df.corr()
plt.figure(figsize=(25,5))
fig = sns.barplot(x=corr.columns,
                  y=corr['deposit']
                  )
plt.xticks(rotation=70);

# %% [markdown]
# ### Разделение выборки на тренировочную и тестовую

# %%
# Разобьем датасет на тренировочную и тестовую выборки
X = df.drop(['deposit'], axis=1)
y = df['deposit']
 
X_train, X_test, y_train, y_test = train_test_split(X,y,stratify=y,random_state=42,test_size=0.33)

# %%
# Размеры выборок
print('Размер обучающей выборки: {}'.format(X_train.shape))
print('Размер тестовой выборки: {}'.format(X_test.shape))
# Out:
# Размер обучающей выборки: (7298, 44)
# Размер тестовой выборки: (3595, 44)

# %%
# нормализуем данные с помощью minmaxsсaler
scaler = preprocessing.MinMaxScaler()
X_train_scaled,X_test_scaled = scaler.fit_transform(X_train),scaler.fit_transform(X_test)

# %% [markdown]
# # Часть 4: Решение задачи классификации: логистическая регрессия и решающие деревья

# %%
# обучим логистическую регрессию и подберем оптимальные гиперпараметры с помощью optuna
def func(trials):
  model_log = linear_model.LogisticRegression(
      penalty=trials.suggest_categorical('penalty',['l2','l1','none']),
      solver='saga',
      n_jobs=-1,
      max_iter=1000,
      random_state=42,
      C=trials.suggest_int('C',low=1,high=6),
      class_weight='balanced' 
  )
  model_log.fit(X_train_scaled,y_train)
  return metrics.f1_score(y_train,model_log.predict(X_train_scaled))
 
study_lm_lg = optuna.create_study(direction='maximize',study_name='LogisticRegression')
study_lm_lg.optimize(n_trials=15,n_jobs=-1,func=func)

ml_lg = linear_model.LogisticRegression(**study_lm_lg.best_params,class_weight='balanced',random_state=42,n_jobs=-1,max_iter=1000,).fit(X_train_scaled,y_train)
# Out:
# [I 2022-12-12 20:03:13,145] A new study created in memory with name: LogisticRegression
# [I 2022-12-12 20:03:13,629] Trial 1 finished with value: 0.8187820983125458 and parameters: {'penalty': 'l2', 'C': 3}. Best is trial 1 with value: 0.8187820983125458.
# [I 2022-12-12 20:03:13,646] Trial 0 finished with value: 0.819407798299619 and parameters: {'penalty': 'l2', 'C': 4}. Best is trial 0 with value: 0.819407798299619.
# [I 2022-12-12 20:03:14,058] Trial 3 finished with value: 0.8197393469029141 and parameters: {'penalty': 'none', 'C': 4}. Best is trial 3 with value: 0.8197393469029141.
# [I 2022-12-12 20:03:14,505] Trial 2 finished with value: 0.8194464782545029 and parameters: {'penalty': 'l1', 'C': 6}. Best is trial 3 with value: 0.8197393469029141.
# [I 2022-12-12 20:03:14,638] Trial 4 finished with value: 0.8192735793790276 and parameters: {'penalty': 'l1', 'C': 3}. Best is trial 3 with value: 0.8197393469029141.
# [I 2022-12-12 20:03:15,043] Trial 6 finished with value: 0.8197393469029141 and parameters: {'penalty': 'none', 'C': 2}. Best is trial 3 with value: 0.8197393469029141.
# [I 2022-12-12 20:03:15,477] Trial 5 finished with value: 0.8194464782545029 and parameters: {'penalty': 'l1', 'C': 6}. Best is trial 3 with value: 0.8197393469029141.
# [I 2022-12-12 20:03:15,735] Trial 7 finished with value: 0.8192206270143568 and parameters: {'penalty': 'l1', 'C': 5}. Best is trial 3 with value: 0.8197393469029141.
# [I 2022-12-12 20:03:15,879] Trial 8 finished with value: 0.8197393469029141 and parameters: {'penalty': 'none', 'C': 3}. Best is trial 3 with value: 0.8197393469029141.
# [I 2022-12-12 20:03:16,330] Trial 9 finished with value: 0.819407798299619 and parameters: {'penalty': 'l2', 'C': 4}. Best is trial 3 with value: 0.8197393469029141.
# [I 2022-12-12 20:03:16,507] Trial 10 finished with value: 0.8192206270143568 and parameters: {'penalty': 'l1', 'C': 4}. Best is trial 3 with value: 0.8197393469029141.
# [I 2022-12-12 20:03:16,760] Trial 11 finished with value: 0.8197393469029141 and parameters: {'penalty': 'none', 'C': 1}. Best is trial 3 with value: 0.8197393469029141.
# [I 2022-12-12 20:03:16,981] Trial 12 finished with value: 0.8197393469029141 and parameters: {'penalty': 'none', 'C': 1}. Best is trial 3 with value: 0.8197393469029141.
# [I 2022-12-12 20:03:17,179] Trial 13 finished with value: 0.8197393469029141 and parameters: {'penalty': 'none', 'C': 1}. Best is trial 3 with value: 0.8197393469029141.
# [I 2022-12-12 20:03:17,362] Trial 14 finished with value: 0.8197393469029141 and parameters: {'penalty': 'none', 'C': 2}. Best is trial 3 with value: 0.8197393469029141.

# %%
# Выведем результаты оптимизации и метрики качества
print("Наилучшие значения гиперпараметров {}".format(study_lm_lg.best_params))
print("f1_score на обучающем наборе: {:.2f}".format(study_lm_lg.best_value))
print(metrics.classification_report(y_test,ml_lg.predict(X_test_scaled)))
# Out:
# Наилучшие значения гиперпараметров {'penalty': 'none', 'C': 4}
# f1_score на обучающем наборе: 0.82
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84      1906
#            1       0.83      0.81      0.82      1689
#
#     accuracy                           0.83      3595
#    macro avg       0.83      0.83      0.83      3595
# weighted avg       0.83      0.83      0.83      3595

# %%
# обучим дерево решений, и подберем гиперпараметры
def func(trials):
  model_tree = tree.DecisionTreeClassifier(
      criterion=trials.suggest_categorical('criterion',['gini','entropy']),
      random_state=42,
      max_depth=trials.suggest_int('max_depth',2,8,1),
      min_samples_split=trials.suggest_int('min_samples_split',2,10,1),
      min_samples_leaf=trials.suggest_int('min_samples_leaf',3,10,1),
      max_features=trials.suggest_categorical('max_features',['auto', 'sqrt', 'log2']),
      class_weight='balanced'
      )
  model_tree.fit(X_train_scaled,y_train)
  tree_pred = model_tree.predict(X_train_scaled) 
  return metrics.f1_score(tree_pred,y_train)

tree_study = optuna.create_study(direction='maximize',study_name='DecisionTreeClassifier')
tree_study.optimize(n_trials=200,n_jobs=-1,func=func) 

model_tree = tree.DecisionTreeClassifier(**tree_study.best_params, class_weight='balanced', random_state=42).fit(X_train_scaled,y_train)
# Out:
# [I 2022-12-12 19:36:31,963] A new study created in memory with name: DecisionTreeClassifier
# [I 2022-12-12 19:36:32,007] Trial 0 finished with value: 0.7444904501135302 and parameters: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 8, 'max_features': 'auto'}. Best is trial 0 with value: 0.7444904501135302.
# [I 2022-12-12 19:36:32,032] Trial 1 finished with value: 0.7757695566224231 and parameters: {'criterion': 'gini', 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 6, 'max_features': 'auto'}. Best is trial 1 with value: 0.7757695566224231.
# [I 2022-12-12 19:36:32,061] Trial 2 finished with value: 0.7313146799540055 and parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': 'auto'}. Best is trial 1 with value: 0.7757695566224231.
# [I 2022-12-12 19:36:32,085] Trial 3 finished with value: 0.7650525236997183 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': 'auto'}. Best is trial 1 with value: 0.7757695566224231.
# [I 2022-12-12 19:36:32,107] Trial 4 finished with value: 0.777641778865769 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 7, 'max_features': 'auto'}. Best is trial 4 with value: 0.777641778865769.
# [I 2022-12-12 19:36:32,129] Trial 5 finished with value: 0.7718604322644442 and parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 6, 'max_features': 'auto'}. Best is trial 4 with value: 0.777641778865769.
# [I 2022-12-12 19:36:32,150] Trial 6 finished with value: 0.7848066298342542 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 8, 'max_features': 'auto'}. Best is trial 6 with value: 0.7848066298342542.
# [I 2022-12-12 19:36:32,165] Trial 7 finished with value: 0.7494657448145821 and parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 6 with value: 0.7848066298342542.
# [I 2022-12-12 19:36:32,184] Trial 8 finished with value: 0.7941258741258742 and parameters: {'criterion': 'gini', 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 8 with value: 0.7941258741258742.
# [I 2022-12-12 19:36:32,203] Trial 9 finished with value: 0.7614984668710839 and parameters: {'criterion': 'gini', 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 'auto'}. Best is trial 8 with value: 0.7941258741258742.
# [I 2022-12-12 19:36:32,235] Trial 10 finished with value: 0.7482556516885291 and parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': 'log2'}. Best is trial 8 with value: 0.7941258741258742.
# [I 2022-12-12 19:36:32,269] Trial 11 finished with value: 0.7216169724770641 and parameters: {'criterion': 'gini', 'max_depth': 2, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 8 with value: 0.7941258741258742.
# [I 2022-12-12 19:36:32,308] Trial 12 finished with value: 0.7607466063348416 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 8 with value: 0.7941258741258742.
# [I 2022-12-12 19:36:32,364] Trial 13 finished with value: 0.7866225839267549 and parameters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 8 with value: 0.7941258741258742.
# [I 2022-12-12 19:36:32,395] Trial 14 finished with value: 0.7960118566424145 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 14 with value: 0.7960118566424145.
# [I 2022-12-12 19:36:32,444] Trial 15 finished with value: 0.7494657448145821 and parameters: {'criterion': 'gini', 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 14 with value: 0.7960118566424145.
# [I 2022-12-12 19:36:32,450] Trial 16 finished with value: 0.7612148230704932 and parameters: {'criterion': 'gini', 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 14 with value: 0.7960118566424145.
# [I 2022-12-12 19:36:32,527] Trial 17 finished with value: 0.7514167560116404 and parameters: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial
and parameters: {'criterion': 'gini', 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 7, 'max_features': 'auto'}. Best is trial 51 with value: 0.8189583907412511.

# %%
print("Наилучшие значения гиперпараметров {}".format(tree_study.best_params))
print("f1_score на обучающем наборе: {:.2f}".format(tree_study.best_value))
print(metrics.classification_report(y_test,model_tree.predict(X_test_scaled)))
# Out:
# Наилучшие значения гиперпараметров {'criterion': 'gini', 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': 'auto'}
# f1_score на обучающем наборе: 0.82
#               precision    recall  f1-score   support
#
#            0       0.85      0.76      0.81      1906
#            1       0.76      0.85      0.80      1689
#
#     accuracy                           0.80      3595
#    macro avg       0.81      0.81      0.80      3595
# weighted avg       0.81      0.80      0.80      3595

# %% [markdown]
# # Часть 5: Решение задачи классификации: ансамбли моделей и построение прогноза

# %%
# обучим на наших данных случайный лес
def func(trials):
  model_forest = ensemble.RandomForestClassifier(
      n_estimators=trials.suggest_int('n_estimators',100,350,1),
      criterion=trials.suggest_categorical('criterion',['gini','entropy']),
      min_samples_leaf=trials.suggest_int('min_samples_leaf',3,10,1),
      max_depth=trials.suggest_int('max_depth',2,8,1),
      max_features=trials.suggest_categorical('max_features',['auto', 'sqrt', 'log2']),
      random_state=42,
      class_weight=trials.suggest_categorical('class_weight',['balanced','balanced_subsample']),
      n_jobs=-1
  )
  model_forest.fit(X_train_scaled,y_train)
  return metrics.f1_score(model_forest.predict(X_train_scaled) ,y_train)

# подберем гиперпараметры 
forest_study = optuna.create_study(direction='maximize',study_name='RandomForestClassifier')
# %time forest_study.optimize(n_trials=100,n_jobs=-1,func=func) 

model_forest = ensemble.RandomForestClassifier(**forest_study.best_params, random_state=42,n_jobs=-1).fit(X_train_scaled,y_train)
# Out:
# [I 2022-12-12 19:36:40,491] A new study created in memory with name: RandomForestClassifier
# [I 2022-12-12 19:36:41,829] Trial 1 finished with value: 0.8484511737741354 and parameters: {'n_estimators': 116, 'criterion': 'gini', 'min_samples_leaf': 10, 'max_depth': 8, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 1 with value: 0.8484511737741354.
# [I 2022-12-12 19:36:43,181] Trial 0 finished with value: 0.8364045576030384 and parameters: {'n_estimators': 237, 'criterion': 'entropy', 'min_samples_leaf': 3, 'max_depth': 6, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 1 with value: 0.8484511737741354.
# [I 2022-12-12 19:36:46,170] Trial 3 finished with value: 0.765024209626887 and parameters: {'n_estimators': 273, 'criterion': 'entropy', 'min_samples_leaf': 7, 'max_depth': 2, 'max_features': 'log2', 'class_weight': 'balanced_subsample'}. Best is trial 1 with value: 0.8484511737741354.
# [I 2022-12-12 19:36:46,934] Trial 2 finished with value: 0.8485269594219009 and parameters: {'n_estimators': 341, 'criterion': 'gini', 'min_samples_leaf': 10, 'max_depth': 7, 'max_features': 'auto', 'class_weight': 'balanced_subsample'}. Best is trial 2 with value: 0.8485269594219009.
# [I 2022-12-12 19:36:47,201] Trial 4 finished with value: 0.7694285714285715 and parameters: {'n_estimators': 122, 'criterion': 'entropy', 'min_samples_leaf': 5, 'max_depth': 2, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 2 with value: 0.8485269594219009.
# [I 2022-12-12 19:36:49,671] Trial 5 finished with value: 0.7903342497467805 and parameters: {'n_estimators': 214, 'criterion': 'entropy', 'min_samples_leaf': 6, 'max_depth': 4, 'max_features': 'log2', 'class_weight': 'balanced_subsample'}. Best is trial 2 with value: 0.8485269594219009.
# [I 2022-12-12 19:36:51,683] Trial 6 finished with value: 0.8499792214988225 and parameters: {'n_estimators': 303, 'criterion': 'gini', 'min_samples_leaf': 5, 'max_depth': 7, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial
}. Best is trial 14 with value: 0.860484544695071.
# [I 2022-12-12 19:37:10,556] Trial 20 finished with value: 0.7827089337175792 and parameters: {'n_estimators': 198, 'criterion': 'gini', 'min_samples_leaf': 4, 'max_depth': 3, 'max_features': 'auto', 'class_weight': 'balanced'}. Best is trial 14 with value: 0.860484544695071.
# [I 2022-12-12 19:37:13,247] Trial 21 finished with value: 0.7828596162169961 and parameters: {'n_estimators': 202, 'criterion': 'gini', 'min_samples_leaf': 5, 'max_depth': 3, 'max_features': 'auto', 'class_weight': 'balanced'}. Best is trial 14 with value: 0.860484544695071.
# [I 2022-12-12 19:37:14,781] Trial 22 finished with value: 0.8550020813098378 and parameters: {'n_estimators': 150, 'criterion': 'gini', 'min_samples_leaf': 8, 'max_depth': 8, 'max_features': 'auto', 'class_weight': 'balanced'}. Best is trial 14 with value: 0.860484544695071.
# [I 2022-12-12 19:37:17,005] Trial 23 finished with value: 0.856032208801888 and parameters: {'n_estimators': 155, 'criterion': 'gini', 'min_samples_leaf': 8, 'max_depth': 8, 'max_features': 'auto', 'class_weight': 'balanced'}. Best is trial 14 with value: 0.860484544695071.
# [I 2022-12-12 19:37:18,387] Trial 24 finished with value: 0.8551609322974473 and parameters: {'n_estimators': 151, 'criterion': 'gini', 'min_samples_leaf': 8, 'max_depth': 8, 'max_features': 'auto', 'class_weight': 'balanced'}. Best is trial 14 with value: 0.860484544695071.
# [I 2022-12-12 19:37:19,315] Trial 25 finished with value: 0.852318339100346 and parameters: {'n_estimators': 104, 'criterion': 'gini', 'min_samples_leaf': 9, 'max_depth': 8, 'max_features': 'auto', 'class_weight': 'balanced'}. Best is trial 14 with value: 0.860484544695071.
# [I 2022-12-12 19:37:20,307] Trial 26 finished with value: 0.8370019504040123 and parameters: {'n_estimators': 104, 'criterion': 'gini', 'min_samples_leaf': 3, 'max_depth': 6, 'max_features': 'auto', 'class_weight': 'balanced'}. Best is trial 14 with value: 0.860484544695071.
# [I 2022-12-12 19:37:24,110] Trial 27 finished with value: 0.8380311316785864 and parameters: {'n_estimators': 177, 'criterion': 'entropy', 'min_samples_leaf': 3, 'max_depth': 6, 'max_features': 'auto', 'class_weight': 'balanced_subsample'}. Best is trial 14 with value: 0.860484544695071.
# [I 2022-12-12 19:37:26,055] Trial 28 finished with value: 0.8504751257685857 and parameters: {'n_estimators': 186, 'criterion': 'entropy', 'min_samples_leaf': 6, 'max_depth': 7, 'max_features': 'auto', 'class_weight': 'balanced_subsample'}. Best is trial 14 with value: 0.860484544695071.
# [I 2022-12-12 19:37:28,609] Trial 29 finished with value: 0.848856664807585 and parameters: {'n_estimators': 222, 'criterion': 'gini', 'min_samples_leaf': 6, 'max_depth': 7, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 14 with value: 0.860484544695071.
# [I 2022-12-12 19:37:29,100] Trial 30 finished with value: 0.849395077179808 and parameters: {'n_estimators': 233, 'criterion': 'gini', 'min_samples_leaf': 7, 'max_depth': 7, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 14 with value: 0.860484544695071.
# [I 2022-12-12 19:37:31,014] Trial 32 finished with value: 0.8516361619523017 and parameters: {'n_estimators': 166, 'criterion': 'gini', 'min_samples_leaf': 9, 'max_depth': 8, 'max_features': 'auto', 'class_weight': 'balanced'}. Best is trial 14 with value: 0.860484544695071.
# [I 2022-12-12 19:37:31,198] Trial 31 finished with value: 0.8541637703322675 and parameters: {'n_estimators': 235, 'criterion': 'gini', 'min_samples_leaf': 7, 'max_depth': 8, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 14 with value: 0.860484544695071.
# [I 2022-12-12 19:37:33,078] Trial 33 finished with value: 0.8504529616724739 and parameters: {'n_estimators': 186, 'criterion': 'gini', 'min_samples_leaf': 8, 'max_depth': 8, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 14 with value: 0.860484544695071.
# [I 2022-12-12 19:37:33,270] Trial 34 finished with value: 0.856071130869686 and parameters: {'n_estimators': 182, 'criterion': 'gini', 'min_samples_leaf': 8, 'max_depth': 8, 'max_features': 'auto', 'class_weight': 'balanced'}. Best is trial 14 with value: 0.860484544695071.
# [I 2022-12-12 19:37:34,756] Trial 36 finished with value: 0.8522727272727272 and parameters: {'n_estimators': 133, 'criterion': 'gini', 'min_samples_leaf': 9, 'max_depth': 8, 'max_features': 'auto', 'class_weight': 'balanced'}. Best is trial 14 with value: 0.860484544695071.
# [I 2022-12-12 19:37:34,767] Trial 35 finished with value: 0.852509010257832 and parameters: {'n_estimators': 135, 'criterion': 'gini', 'min_samples_leaf': 9, 'max_depth': 8, 'max_features': 'auto', 'class_weight': 'balanced'}. Best is trial 14 with value: 0.860484544695071.
# [I 2022-12-12 19:37:36,466] Trial 37 finished with value: 0.8404701931150294 and parameters: {'n_estimators': 141, 'criterion': 'entropy', 'min_samples_leaf': 5, 'max_depth': 7, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 14 with value: 0.860484544695071.
# [I 2022-12-12 19:37:37,246] Trial 38 finished with value: 0.8436800894854586 and parameters: {'n_estimators': 207, 'criterion': 'entropy', 'min_samples_leaf': 5, 'max_depth': 7, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 14 with value: 0.860484544695071.
# [I 2022-12-12 19:37:39,417] Trial 40 finished with value: 0.8255127844900253 and parameters: {'n_estimators': 162, 'criterion': 'gini', 'min_samples_leaf': 10, 'max_depth': 5, 'max_features': 'auto', 'class_weight': 'balanced_subsample'}. Best is trial 14 with value: 0.860484544695071.
# [I 2022-12-12 19:37:39,826] Trial 39 finished with value: 0.8470392455970046 and parameters: {'n_estimators': 215, 'criterion': 'gini', 'min_samples_leaf': 10, 'max_depth': 7, 'max_features': 'auto', 'class_weight': 'balanced_subsample'}. Best is trial 14 with value: 0.860484544695071.
# [I 2022-12-12 19:37:42,046] Trial 42 finished with value: 0.8569446371583184 and parameters: {'n_estimators': 189, 'criterion': 'gini', 'min_samples_leaf': 8, 'max_depth': 8, 'max_features': 'auto', 'class_weight': 'balanced'}. Best is trial 14 with value: 0.860484544695071.
# [I 2022-12-12 19:37:43,131] Trial 41 finished with value: 0.8394751535455053 and parameters: {'n_estimators': 259, 'criterion': 'gini', 'min_samples_leaf': 7, 'max_depth': 6, 'max_features': 'auto', 'class_weight': 'balanced_subsample'}. Best is trial 14 with value: 0.860484544695071.
# [I 2022-12-12 19:37:44,250] Trial 43 finished with value: 0.8548387096774194 and parameters: {'n_estimators': 191, 'criterion': 'gini', 'min_samples_leaf': 7, 'max_depth': 8, 'max_features': 'auto', 'class_weight': 'balanced'}. Best is trial 14 with value: 0.860484544695071.
# [I 2022-12-12 19:37:45,440] Trial 44 finished with value: 0.8569841710635935 and parameters: {'n_estimators': 194, 'criterion': 'gini', 'min_samples_leaf': 8, 'max_depth': 8, 'max_features': 'auto', 'class_weight': 'balanced'}. Best is trial 14 with value: 0.860484544695071.
# [I 2022-12-12 19:37:46,199] Trial 45 finished with value: 0.8571428571428572 and parameters: {'n_estimators': 164, 'criterion': 'gini', 'min_samples_leaf': 8, 'max_depth': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 14 with value: 0.860484544695071.
# [I 2022-12-12 19:37:47,991] Trial 46 finished with value: 0.8617095205003474 and parameters: {'n_estimators': 216, 'criterion': 'gini', 'min_samples_leaf': 3, 'max_depth': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 46 with value: 0.8617095205003474.
# [I 2022-12-12 19:37:48,377] Trial 47 finished with value: 0.8517025712300208 and parameters: {'n_estimators': 191, 'criterion': 'gini', 'min_samples_leaf': 3, 'max_depth': 7, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 46 with value: 0.8617095205003474.
# [I 2022-12-12 19:37:50,892] Trial 49 finished with value: 0.8487571970228901 and parameters: {'n_estimators': 220, 'criterion': 'entropy', 'min_samples_leaf': 4, 'max_depth': 7, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 46 with value: 0.8617095205003474.
# [I 2022-12-12 19:37:51,181] Trial 48 finished with value: 0.8528754885538805 and parameters: {'n_estimators': 254, 'criterion': 'entropy', 'min_samples_leaf': 3, 'max_depth': 7, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 46 with value: 0.8617095205003474.
# [I 2022-12-12 19:37:52,752] Trial 51 finished with value: 0.7988513998564251 and parameters: {'n_estimators': 119, 'criterion': 'gini', 'min_samples_leaf': 4, 'max_depth': 4, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 46 with value: 0.8617095205003474.
# [I 2022-12-12 19:37:55,631] Trial 50 finished with value: 0.7947573095203802 and parameters: {'n_estimators': 291, 'criterion': 'gini', 'min_samples_leaf': 3, 'max_depth':
 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 53 with value: 0.8619491171972751.
# [I 2022-12-12 19:38:36,790] Trial 78 finished with value: 0.8524087997772208 and parameters: {'n_estimators': 271, 'criterion': 'gini', 'min_samples_leaf': 4, 'max_depth': 7, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 53 with value: 0.8619491171972751.
# [I 2022-12-12 19:38:38,959] Trial 80 finished with value: 0.8592448639644642 and parameters: {'n_estimators': 227, 'criterion': 'gini', 'min_samples_leaf': 4, 'max_depth': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 53 with value: 0.8619491171972751.
# [I 2022-12-12 19:38:39,423] Trial 81 finished with value: 0.8612347052280311 and parameters: {'n_estimators': 223, 'criterion': 'gini', 'min_samples_leaf': 3, 'max_depth': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 53 with value: 0.8619491171972751.
# [I 2022-12-12 19:38:41,529] Trial 82 finished with value: 0.8618293021962746 and parameters: {'n_estimators': 215, 'criterion': 'gini', 'min_samples_leaf': 3, 'max_depth': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 53 with value: 0.8619491171972751.
# [I 2022-12-12 19:38:42,057] Trial 83 finished with value: 0.8612347052280311 and parameters: {'n_estimators': 218, 'criterion': 'gini', 'min_samples_leaf': 3, 'max_depth': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 53 with value: 0.8619491171972751.
# [I 2022-12-12 19:38:44,119] Trial 84 finished with value: 0.8613930209926317 and parameters: {'n_estimators': 213, 'criterion': 'gini', 'min_samples_leaf': 3, 'max_depth': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 53 with value: 0.8619491171972751.
# [I 2022-12-12 19:38:44,605] Trial 85 finished with value: 0.8590827213523624 and parameters: {'n_estimators': 217, 'criterion': 'gini', 'min_samples_leaf': 3, 'max_depth': 8, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 53 with value: 0.8619491171972751.
# [I 2022-12-12 19:38:46,614] Trial 87 finished with value: 0.8292273236282194 and parameters: {'n_estimators': 212, 'criterion': 'gini', 'min_samples_leaf': 5, 'max_depth': 5, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 53 with value: 0.8619491171972751.
# [I 2022-12-12 19:38:46,812] Trial 86 finished with value: 0.8618293021962746 and parameters: {'n_estimators': 217, 'criterion': 'gini', 'min_samples_leaf': 3, 'max_depth': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 53 with value: 0.8619491171972751.
# [I 2022-12-12 19:38:49,098] Trial 88 finished with value: 0.8618293021962746 and parameters: {'n_estimators': 198, 'criterion': 'gini', 'min_samples_leaf': 3, 'max_depth': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 53 with value: 0.8619491171972751.
# [I 2022-12-12 19:38:49,224] Trial 89 finished with value: 0.8615512927439533 and parameters: {'n_estimators': 201, 'criterion': 'gini', 'min_samples_leaf': 3, 'max_depth': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 53 with value: 0.8619491171972751.
# [I 2022-12-12 19:38:51,540] Trial 91 finished with value: 0.8519755147468003 and parameters: {'n_estimators': 202, 'criterion': 'gini', 'min_samples_leaf': 4, 'max_depth': 7, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 53 with value: 0.8619491171972751.
# [I 2022-12-12 19:38:51,728] Trial 90 finished with value: 0.8586911213005419 and parameters: {'n_estimators': 199, 'criterion': 'entropy', 'min_samples_leaf': 4, 'max_depth': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 53 with value: 0.8619491171972751.
# [I 2022-12-12 19:38:54,026] Trial 92 finished with value: 0.8615512927439533 and parameters: {'n_estimators': 199, 'criterion': 'gini', 'min_samples_leaf': 3, 'max_depth': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 53 with value: 0.8619491171972751.
# [I 2022-12-12 19:38:54,996] Trial 93 finished with value: 0.8609915289543119 and parameters: {'n_estimators': 238, 'criterion': 'gini', 'min_samples_leaf': 3, 'max_depth': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 53 with value: 0.8619491171972751.
# [I 2022-12-12 19:38:58,620] Trial 94 finished with value: 0.8609915289543119 and parameters: {'n_estimators': 238, 'criterion': 'gini', 'min_samples_leaf': 3, 'max_depth': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 53 with value: 0.8619491171972751.
# [I 2022-12-12 19:38:58,984] Trial 95 finished with value: 0.8609603340292274 and parameters: {'n_estimators': 184, 'criterion': 'gini', 'min_samples_leaf': 3, 'max_depth': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 53 with value: 0.8619491171972751.
# [I 2022-12-12 19:39:01,043] Trial 96 finished with value: 0.8582120582120581 and parameters: {'n_estimators': 196, 'criterion': 'gini', 'min_samples_leaf': 3, 'max_depth': 8, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 53 with value: 0.8619491171972751.
# [I 2022-12-12 19:39:01,276] Trial 97 finished with value: 0.8582120582120581 and parameters: {'n_estimators': 196, 'criterion': 'gini', 'min_samples_leaf': 3, 'max_depth': 8, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 53 with value: 0.8619491171972751.
# [I 2022-12-12 19:39:03,528] Trial 98 finished with value: 0.8620641755799417 and parameters: {'n_estimators': 203, 'criterion': 'gini', 'min_samples_leaf': 3, 'max_depth': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 98 with value: 0.8620641755799417.
# [I 2022-12-12 19:39:03,587] Trial 99 finished with value: 0.859088382434686 and parameters: {'n_estimators': 208, 'criterion': 'gini', 'min_samples_leaf': 4, 'max_depth': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 98 with value: 0.8620641755799417.
# CPU times: user 3min 18s, sys: 10.4 s, total: 3min 29s
# Wall time: 2min 23s

# %%
print("Наилучшие значения гиперпараметров {}".format(forest_study.best_params))
print("f1_score на обучающем наборе: {:.2f}".format(forest_study.best_value))
print(metrics.classification_report(y_test,model_forest.predict(X_test_scaled)))
# Out:
# Наилучшие значения гиперпараметров {'n_estimators': 203, 'criterion': 'gini', 'min_samples_leaf': 3, 'max_depth': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}
# f1_score на обучающем наборе: 0.86
#               precision    recall  f1-score   support
#
#            0       0.90      0.80      0.84      1906
#            1       0.80      0.90      0.84      1689
#
#     accuracy                           0.84      3595
#    macro avg       0.85      0.85      0.84      3595
# weighted avg       0.85      0.84      0.84      3595

# %%
# используем для классификации градиентный бустинг, подберем оптимальные параметры
def func(trials):
  ensemble_boosting = ensemble.GradientBoostingClassifier(
      loss= trials.suggest_categorical('loss',['deviance', 'exponential']),
      learning_rate=trials.suggest_float('learning_rate',low=0.01,high=0.07,step=0.001),
      n_estimators=trials.suggest_int('n_estimators',200,250,1),
      min_samples_leaf=trials.suggest_int('min_samples_leaf',3,10,1),
      max_depth=trials.suggest_int('max_depth',2,5,1),
      criterion = trials.suggest_categorical('criterion',['friedman_mse', 'squared_error']),
      max_features=trials.suggest_categorical('max_features',['auto', 'sqrt', 'log2']),
      random_state=42
      )
  ensemble_boosting.fit(X_train_scaled,y_train)
  return metrics.f1_score(y_train,ensemble_boosting.predict(X_train_scaled))

boost_study = optuna.create_study(direction='maximize',study_name='GradientBoostingClassifier')
# %time boost_study.optimize(n_trials=50,func=func,n_jobs=-1)
# обучим модель на подобранных параметрах
ensemble_boosting = ensemble.GradientBoostingClassifier(**boost_study.best_params,random_state=42).fit(X_train_scaled,y_train)
# Out:
# [I 2022-12-12 19:39:06,030] A new study created in memory with name: GradientBoostingClassifier
# [I 2022-12-12 19:39:09,595] Trial 0 finished with value: 0.886104783599089 and parameters: {'loss': 'deviance', 'learning_rate': 0.061000000000000006, 'n_estimators': 230, 'min_samples_leaf': 5, 'max_depth': 5, 'criterion': 'squared_error', 'max_features': 'sqrt'}. Best is trial 0 with value: 0.886104783599089.
# [I 2022-12-12 19:39:10,992] Trial 2 finished with value: 0.8432760364004044 and parameters: {'loss': 'exponential', 'learning_rate': 0.047, 'n_estimators': 234, 'min_samples_leaf': 9, 'max_depth': 3, 'criterion': 'squared_error', 'max_features': 'log2'}. Best is trial 0 with value: 0.886104783599089.
# [I 2022-12-12 19:39:12,679] Trial 3 finished with value: 0.835435696679716 and parameters: {'loss': 'exponential', 'learning_rate': 0.013000000000000001, 'n_estimators': 214, 'min_samples_leaf': 5, 'max_depth': 4, 'criterion': 'friedman_mse', 'max_features': 'sqrt'}. Best is trial 0 with value: 0.886104783599089.
# [I 2022-12-12 19:39:15,204] Trial 1 finished with value: 0.8522111269614836 and parameters: {'loss': 'deviance', 'learning_rate': 0.015, 'n_estimators': 219, 'min_samples_leaf': 9, 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 0 with value: 0.886104783599089.
# [I 2022-12-12 19:39:18,788] Trial 5 finished with value: 0.8377129656367311 and parameters: {'loss': 'deviance', 'learning_rate': 0.05, 'n_estimators': 248, 'min_samples_leaf': 3, 'max_depth': 2, 'criterion': 'squared_error', 'max_features': 'auto'}. Best is trial 0 with value: 0.886104783599089.
# [I 2022-12-12 19:39:19,991] Trial 4 finished with value: 0.8976757369614512 and parameters: {'loss': 'exponential', 'learning_rate': 0.068, 'n_estimators': 218, 'min_samples_leaf': 10, 'max_depth': 5, 'criterion': 'squared_error', 'max_features': 'auto'}. Best is trial 4 with value: 0.8976757369614512.
# [I 2022-12-12 19:39:21,398] Trial 6 finished with value: 0.846551724137931 and parameters: {'loss': 'deviance', 'learning_rate': 0.024, 'n_estimators': 231, 'min_samples_leaf': 8, 'max_depth': 4, 'criterion': 'friedman_mse', 'max_features': 'sqrt'}. Best is trial 4 with value: 0.8976757369614512.
# [I 2022-12-12 19:39:23,371] Trial 7 finished with value: 0.8465958058029301 and parameters: {'loss': 'exponential', 'learning_rate': 0.032, 'n_estimators': 204, 'min_samples_leaf': 3, 'max_depth': 4, 'criterion': 'squared_error', 'max_features': 'log2'}. Best is trial 4 with value: 0.8976757369614512.
# [I 2022-12-12 19:39:24,428] Trial 8 finished with value: 0.857347670250896 and parameters: {'loss': 'deviance', 'learning_rate': 0.069, 'n_estimators': 249, 'min_samples_leaf': 3, 'max_depth': 3, 'criterion': 'squared_error', 'max_features': 'sqrt'}. Best is trial 4 with value: 0.8976757369614512.
# [I 2022-12-12 19:39:26,007] Trial 10 finished with value: 0.8457208832443355 and parameters: {'loss': 'exponential', 'learning_rate': 0.065, 'n_estimators': 225, 'min_samples_leaf': 5, 'max_depth': 3, 'criterion': 'friedman_mse', 'max_features': 'log2'}. Best is trial 4 with value: 0.8976757369614512.
# [I 2022-12-12 19:39:26,222] Trial 9 finished with value: 0.862241256245539 and parameters: {'loss': 'exponential', 'learning_rate': 0.039, 'n_estimators': 217, 'min_samples_leaf': 5, 'max_depth': 5, 'criterion': 'squared_error', 'max_features': 'sqrt'}. Best is trial 4 with value: 0.8976757369614512.
# [I 2022-12-12 19:39:32,961] Trial 11 finished with value: 0.8835432290929673 and parameters: {'loss': 'exponential', 'learning_rate': 0.051000000000000004, 'n_estimators': 203, 'min_samples_leaf': 10, 'max_depth': 5, 'criterion': 'squared_error', 'max_features': 'auto'}. Best is trial 4 with value: 0.8976757369614512.
# [I 2022-12-12 19:39:34,426] Trial 12 finished with value: 0.9024217532927347 and parameters: {'loss': 'deviance', 'learning_rate': 0.060000000000000005, 'n_estimators': 235, 'min_samples_leaf': 7, 'max_depth': 5, 'criterion': 'squared_error', 'max_features': 'auto'}. Best is trial 12 with value: 0.9024217532927347.
# [I 2022-12-12 19:39:42,644] Trial 13 finished with value: 0.9029607593143505 and parameters: {'loss': 'deviance', 'learning_rate': 0.060000000000000005, 'n_estimators': 237, 'min_samples_leaf': 7, 'max_depth': 5, 'criterion': 'squared_error', 'max_features': 'auto'}. Best is trial 13 with value: 0.9029607593143505.
# [I 2022-12-12 19:39:43,622] Trial 14 finished with value: 0.9046538024971623 and parameters: {'loss': 'deviance', 'learning_rate': 0.057, 'n_estimators': 239, 'min_samples_leaf': 7, 'max_depth': 5, 'criterion': 'squared_error', 'max_features': 'auto'}. Best is trial 14 with value: 0.9046538024971623.
# [I 2022-12-12 19:39:49,023] Trial 15 finished with value: 0.8782423812898654 and parameters: {'loss': 'deviance', 'learning_rate': 0.057, 'n_estimators': 239, 'min_samples_leaf': 7, 'max_depth': 4, 'criterion': 'squared_error', 'max_features': 'auto'}. Best is trial 14 with value: 0.9046538024971623.
# [I 2022-12-12 19:39:50,021] Trial 16 finished with value: 0.8783458433649625 and parameters: {'loss': 'deviance', 'learning_rate': 0.055, 'n_estimators': 242, 'min_samples_leaf': 7, 'max_depth': 4, 'criterion': 'squared_error', 'max_features': 'auto'}. Best is trial 14 with value: 0.9046538024971623.
# [I 2022-12-12 19:39:52,537] Trial 17 finished with value: 0.8314736994638459 and parameters: {'loss': 'deviance', 'learning_rate': 0.041, 'n_estimators': 240, 'min_samples_leaf': 6, 'max_depth': 2, 'criterion': 'squared_error', 'max_features': 'auto'}. Best is trial 14 with value: 0.9046538024971623.
# [I 2022-12-12 19:39:53,493] Trial 18 finished with value: 0.8314736994638459 and parameters: {'loss': 'deviance', 'learning_rate': 0.041, 'n_estimators': 240, 'min_samples_leaf': 6, 'max_depth': 2, 'criterion': 'squared_error', 'max_features': 'auto'}. Best is trial 14 with value: 0.9046538024971623.
# [I 2022-12-12 19:40:00,572] Trial 19 finished with value: 0.8935808417174436 and parameters: {'loss': 'deviance', 'learning_rate': 0.044000000000000004, 'n_estimators': 244, 'min_samples_leaf': 8, 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 14 with value: 0.9046538024971623.
# [I 2022-12-12 19:40:00,966] Trial 20 finished with value: 0.9060145030570169 and parameters: {'loss': 'deviance', 'learning_rate': 0.064, 'n_estimators': 227, 'min_samples_leaf': 8, 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 20 with value: 0.9060145030570169.
# [I 2022-12-12 19:40:02,269] Trial 21 finished with value: 0.8506372619218101 and parameters: {'loss': 'deviance', 'learning_rate': 0.033, 'n_estimators': 225, 'min_samples_leaf': 8, 'max_depth': 4, 'criterion': 'squared_error', 'max_features': 'log2'}. Best is trial 20 with value: 0.9060145030570169.
# [I 2022-12-12 19:40:08,409] Trial 22 finished with value: 0.9030793245352633 and parameters: {'loss': 'deviance', 'learning_rate': 0.061000000000000006, 'n_estimators': 224, 'min_samples_leaf': 8, 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 20 with value: 0.9060145030570169.
# [I 2022-12-12 19:40:09,699] Trial 23 finished with value: 0.9061433447098977 and parameters: {'loss': 'deviance', 'learning_rate': 0.064, 'n_estimators': 228, 'min_samples_leaf': 8, 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 23 with value: 0.9061433447098977.
# [I 2022-12-12 19:40:15,386] Trial 24 finished with value: 0.9027955158223356 and parameters: {'loss': 'deviance', 'learning_rate': 0.064, 'n_estimators': 211, 'min_samples_leaf': 9, 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 23 with value: 0.9061433447098977.
# [I 2022-12-12 19:40:16,646] Trial 25 finished with value: 0.9004968062455643 and parameters: {'loss': 'deviance', 'learning_rate': 0.066, 'n_estimators': 209, 'min_samples_leaf': 9, 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 23 with value: 0.9061433447098977.
# [I 2022-12-12 19:40:21,521] Trial 26 finished with value: 0.8794105143828822 and parameters: {'loss': 'deviance', 'learning_rate': 0.054, 'n_estimators': 230, 'min_samples_leaf': 6, 'max_depth': 4, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 23 with value: 0.9061433447098977.
# [I 2022-12-12 19:40:22,749] Trial 27 finished with value: 0.8793201133144476 and parameters: {'loss': 'deviance', 'learning_rate': 0.054, 'n_estimators': 228, 'min_samples_leaf': 6, 'max_depth': 4, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 23 with value: 0.9061433447098977.
# [I 2022-12-12 19:40:27,369] Trial 28 finished with value: 0.8848931049129265 and parameters: {'loss': 'deviance', 'learning_rate': 0.06999999999999999, 'n_estimators': 222, 'min_samples_leaf': 8, 'max_depth': 4, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 23 with value: 0.9061433447098977.
# [I 2022-12-12 19:40:29,384] Trial 30 finished with value: 0.8873720136518771 and parameters: {'loss': 'deviance', 'learning_rate': 0.063, 'n_estimators': 234, 'min_samples_leaf': 4, 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'log2'}. Best is trial 23 with value: 0.9061433447098977.
# [I 2022-12-12 19:40:30,191] Trial 29 finished with value: 0.9066590779738191 and parameters: {'loss': 'deviance', 'learning_rate': 0.06999999999999999, 'n_estimators': 222, 'min_samples_leaf': 8, 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 29 with value: 0.9066590779738191.
# [I 2022-12-12 19:40:31,690] Trial 31 finished with value: 0.8843304843304844 and parameters: {'loss': 'deviance', 'learning_rate': 0.058, 'n_estimators': 245, 'min_samples_leaf': 7, 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'sqrt'}. Best is trial 29 with value: 0.9066590779738191.
# [I 2022-12-12 19:40:37,414] Trial 32 finished with value: 0.9088323140378325 and parameters: {'loss': 'deviance', 'learning_rate': 0.06999999999999999, 'n_estimators': 220, 'min_samples_leaf': 7, 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 32 with value: 0.9088323140378325.
# [I 2022-12-12 19:40:39,102] Trial 33 finished with value: 0.9045183290707588 and parameters: {'loss': 'deviance', 'learning_rate': 0.066, 'n_estimators': 229, 'min_samples_leaf': 8, 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 32 with value: 0.9088323140378325.
# [I 2022-12-12 19:40:44,505] Trial 34 finished with value: 0.904382470119522 and parameters: {'loss': 'deviance', 'learning_rate': 0.06999999999999999, 'n_estimators': 220, 'min_samples_leaf': 9, 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 32 with value: 0.9088323140378325.
# [I 2022-12-12 19:40:46,220] Trial 35 finished with value: 0.9045926347220247 and parameters: {'loss': 'deviance', 'learning_rate': 0.06999999999999999, 'n_estimators': 221, 'min_samples_leaf': 9, 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 32 with value: 0.9088323140378325.
# [I 2022-12-12 19:40:51,496] Trial 36 finished with value: 0.8995881266865502 and parameters: {'loss': 'deviance', 'learning_rate': 0.063, 'n_estimators': 214, 'min_samples_leaf': 9, 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 32 with value: 0.9088323140378325.
# [I 2022-12-12 19:40:53,294] Trial 37 finished with value: 0.9005681818181819 and parameters: {'loss': 'deviance', 'learning_rate': 0.062000000000000006, 'n_estimators': 216, 'min_samples_leaf': 8, 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 32 with value: 0.9088323140378325.
# [I 2022-12-12 19:40:54,659] Trial 39 finished with value: 0.8432448036951501 and parameters: {'loss': 'exponential', 'learning_rate': 0.05, 'n_estimators': 227, 'min_samples_leaf': 10, 'max_depth': 3, 'criterion': 'friedman_mse', 'max_features': 'log2'}. Best is trial 32 with value: 0.9088323140378325.
# [I 2022-12-12 19:40:59,219] Trial 38 finished with value: 0.8567774936061381 and parameters: {'loss': 'exponential', 'learning_rate': 0.019000000000000003, 'n_estimators': 227, 'min_samples_leaf': 10, 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 32 with value: 0.9088323140378325.
# [I 2022-12-12 19:41:00,760] Trial 40 finished with value: 0.8449778539791398 and parameters: {'loss': 'deviance', 'learning_rate': 0.019000000000000003, 'n_estimators': 223, 'min_samples_leaf': 8, 'max_depth': 4, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 32 with value: 0.9088323140378325.
# [I 2022-12-12 19:41:01,065] Trial 41 finished with value: 0.8676008006863024 and parameters: {'loss': 'deviance', 'learning_rate': 0.066, 'n_estimators': 232, 'min_samples_leaf': 8, 'max_depth': 4, 'criterion': 'friedman_mse', 'max_features': 'sqrt'}. Best is trial 32 with value: 0.9088323140378325.
# [I 2022-12-12 19:41:02,973] Trial 42 finished with value: 0.8877522023302076 and parameters: {'loss': 'deviance', 'learning_rate': 0.066, 'n_estimators': 232, 'min_samples_leaf': 7, 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'sqrt'}. Best is trial 32 with value: 0.9088323140378325.
# [I 2022-12-12 19:41:08,389] Trial 43 finished with value: 0.907902217168846 and parameters: {'loss': 'deviance', 'learning_rate': 0.067, 'n_estimators': 219, 'min_samples_leaf': 7, 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 32 with value: 0.9088323140378325.
# [I 2022-12-12 19:41:10,112] Trial 44 finished with value: 0.9003543586109143 and parameters: {'loss': 'deviance', 'learning_rate': 0.057, 'n_estimators': 219, 'min_samples_leaf': 7, 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 32 with value: 0.9088323140378325.
# [I 2022-12-12 19:41:15,422] Trial 45 finished with value: 0.9085746734809766 and parameters: {'loss': 'deviance', 'learning_rate': 0.068, 'n_estimators': 218, 'min_samples_leaf': 6, 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 32 with value: 0.9088323140378325.
# [I 2022-12-12 19:41:17,143] Trial 46 finished with value: 0.9075152720556898 and parameters: {'loss': 'deviance', 'learning_rate': 0.068, 'n_estimators': 216, 'min_samples_leaf': 6, 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 32 with value: 0.9088323140378325.
# [I 2022-12-12 19:41:19,500] Trial 48 finished with value: 0.8793374268170784 and parameters: {'loss': 'exponential', 'learning_rate': 0.068, 'n_estimators': 210, 'min_samples_leaf': 5, 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'log2'}. Best is trial 32 with value: 0.9088323140378325.
# [I 2022-12-12 19:41:23,032] Trial 47 finished with value: 0.8956829440905875 and parameters: {'loss': 'exponential', 'learning_rate': 0.067, 'n_estimators': 210, 'min_samples_leaf': 6, 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 32 with value: 0.9088323140378325.
# [I 2022-12-12 19:41:25,287] Trial 49 finished with value: 0.9072574918335463 and parameters: {'loss': 'deviance', 'learning_rate': 0.068, 'n_estimators': 214, 'min_samples_leaf': 6, 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 32 with value: 0.9088323140378325.
# CPU times: user 4min 11s, sys: 1.45 s, total: 4min 12s
# Wall time: 2min 19s

# %%
print("Наилучшие значения гиперпараметров {}".format(boost_study.best_params))
print("f1_score на обучающем наборе: {:.2f}".format(boost_study.best_value))
print(metrics.classification_report(y_test,ensemble_boosting.predict(X_test_scaled)))
# Out:
# Наилучшие значения гиперпараметров {'loss': 'deviance', 'learning_rate': 0.06999999999999999, 'n_estimators': 220, 'min_samples_leaf': 7, 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'auto'}
# f1_score на обучающем наборе: 0.91
#               precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86      1906
#            1       0.82      0.89      0.86      1689
#
#     accuracy                           0.86      3595
#    macro avg       0.86      0.86      0.86      3595
# weighted avg       0.86      0.86      0.86      3595

# %%
# посмотрим какие признаки демонстрируют наибольшую  важность в модели градиентного бустинга
values = ensemble_boosting.feature_importances_
labels = X_train.columns
pd.DataFrame(data=values,index=labels,columns=['importance']).sort_values(by='importance',ascending=False)[:7:]
# Out:
#                   importance
# duration            0.436239
# poutcome_success    0.106239
# contact_unknown     0.081362
# housing             0.046146
# balance             0.044801
# day                 0.042936
# pdays               0.031282

# %%
# попробуем использовать ансамбль из моделей, которые до этого обучали и посмотрим итоговый результат
def func(trials):
  # Базовыми моделями будут случайный лес, логистическая регрессия и градиентный бустинг
  estimators = [
    ('rf',ensemble.RandomForestClassifier(**forest_study.best_params,random_state=42,n_jobs=-1)),
    ('gb',ensemble.GradientBoostingClassifier(**boost_study.best_params,random_state=42)),
    ('tr',tree.DecisionTreeClassifier(**tree_study.best_params,class_weight='balanced',random_state=42))
  ]
  # финальной моделью будет логистическая регрессия
  final_estimator = linear_model.LogisticRegression(
      penalty=trials.suggest_categorical('penalty',['l2','l1','none']),
      solver='saga',
      n_jobs=-1,
      max_iter=1000,
      random_state=42,
      C=trials.suggest_int('C',low=1,high=6),
      class_weight='balanced' 
  )
  
  model_stack = ensemble.StackingClassifier(
    estimators=estimators,
    final_estimator=final_estimator,
    n_jobs=-1,
    passthrough=True,
    cv=StratifiedKFold(5))
  
  model_stack.fit(X_train_scaled,y_train)
  return metrics.f1_score(y_train,model_stack.predict(X_train_scaled))

stack_study = optuna.create_study(direction='maximize',study_name='StackingClassifier')
# %time stack_study.optimize(n_trials=15,func=func,n_jobs=-1)
# Out:
# [I 2022-12-12 20:06:12,126] A new study created in memory with name: StackingClassifier
# [I 2022-12-12 20:07:00,421] Trial 0 finished with value: 0.8974576271186442 and parameters: {'penalty': 'l2', 'C': 4}. Best is trial 0 with value: 0.8974576271186442.
# [I 2022-12-12 20:07:08,666] Trial 1 finished with value: 0.896853393537463 and parameters: {'penalty': 'none', 'C': 3}. Best is trial 0 with value: 0.8974576271186442.
# [I 2022-12-12 20:07:54,082] Trial 2 finished with value: 0.8974286521616275 and parameters: {'penalty': 'l2', 'C': 3}. Best is trial 0 with value: 0.8974576271186442.
# [I 2022-12-12 20:08:00,135] Trial 3 finished with value: 0.8974178072527162 and parameters: {'penalty': 'l1', 'C': 5}. Best is trial 0 with value: 0.8974576271186442.
# [I 2022-12-12 20:08:42,541] Trial 4 finished with value: 0.8976422419878582 and parameters: {'penalty': 'l2', 'C': 2}. Best is trial 4 with value: 0.8976422419878582.
# [I 2022-12-12 20:08:49,010] Trial 5 finished with value: 0.8974178072527162 and parameters: {'penalty': 'l1', 'C': 4}. Best is trial 4 with value: 0.8976422419878582.
# [I 2022-12-12 20:09:30,289] Trial 6 finished with value: 0.896853393537463 and parameters: {'penalty': 'none', 'C': 6}. Best is trial 4 with value: 0.8976422419878582.
# [I 2022-12-12 20:09:37,192] Trial 7 finished with value: 0.8976422419878582 and parameters: {'penalty': 'l2', 'C': 2}. Best is trial 4 with value: 0.8976422419878582.
# [I 2022-12-12 20:10:18,562] Trial 8 finished with value: 0.8975444538526672 and parameters: {'penalty': 'l1', 'C': 3}. Best is trial 4 with value: 0.8976422419878582.
# [I 2022-12-12 20:10:24,308] Trial 9 finished with value: 0.8974178072527162 and parameters: {'penalty': 'l1', 'C': 4}. Best is trial 4 with value: 0.8976422419878582.
# [I 2022-12-12 20:11:05,584] Trial 10 finished with value: 0.896853393537463 and parameters: {'penalty': 'none', 'C': 3}. Best is trial 4 with value: 0.8976422419878582.
# [I 2022-12-12 20:11:13,749] Trial 11 finished with value: 0.8976823063877896 and parameters: {'penalty': 'l2', 'C': 1}. Best is trial 11 with value: 0.8976823063877896.
# [I 2022-12-12 20:11:58,302] Trial 12 finished with value: 0.8976823063877896 and parameters: {'penalty': 'l2', 'C': 1}. Best is trial 11 with value: 0.8976823063877896.
# [I 2022-12-12 20:12:06,283] Trial 13 finished with value: 0.8976823063877896 and parameters: {'penalty': 'l2', 'C': 1}. Best is trial 11 with value: 0.8976823063877896.
# [I 2022-12-12 20:12:27,699] Trial 14 finished with value: 0.8976823063877896 and parameters: {'penalty': 'l2', 'C': 1}. Best is trial 11 with value: 0.8976823063877896.
# CPU times: user 21.2 s, sys: 1.83 s, total: 23.1 s
# Wall time: 6min 15s

# %%
# обучим модель с полученными параметрами 
estimators = [
   ('rf',ensemble.RandomForestClassifier(**forest_study.best_params,random_state=42,n_jobs=-1)),
    ('gb',ensemble.GradientBoostingClassifier(**boost_study.best_params,random_state=42)),
    ('tr',tree.DecisionTreeClassifier(**tree_study.best_params,class_weight='balanced',random_state=42))
    ]
final_estimator = linear_model.LogisticRegression(**stack_study.best_params,random_state=42,max_iter=1000,n_jobs=-1)

ensemble_stack = ensemble.StackingClassifier( estimators=estimators,
                                             final_estimator=final_estimator,
                                             n_jobs=-1,
                                             passthrough=True,
                                             cv=StratifiedKFold(5)).fit(X_train_scaled,y_train)

# %%
print("Наилучшие значения гиперпараметров {}".format(stack_study.best_params))
print("f1_score на обучающем наборе: {:.2f}".format(stack_study.best_value))
print(metrics.classification_report(y_test,ensemble_stack.predict(X_test_scaled)))
# Out:
# Наилучшие значения гиперпараметров {'penalty': 'l2', 'C': 1}
# f1_score на обучающем наборе: 0.90
#               precision    recall  f1-score   support
#
#            0       0.89      0.84      0.86      1906
#            1       0.83      0.88      0.85      1689
#
#     accuracy                           0.86      3595
#    macro avg       0.86      0.86      0.86      3595
# weighted avg       0.86      0.86      0.86      3595

# %% [markdown]
# ### Итоговые результаты

# %%
print('Результат LogisticRegression:', '\n', metrics.classification_report(y_test,ml_lg.predict(X_test_scaled)))
print('--------------------------------------------------------')
print('Результат DecisionTreeClassifier:', '\n', metrics.classification_report(y_test,model_tree.predict(X_test_scaled)))
print('--------------------------------------------------------')
print('Результат RandomForestClassifier:', '\n', metrics.classification_report(y_test,model_forest.predict(X_test_scaled)))
print('--------------------------------------------------------')
print('Результат GradientBoostingClassifier:','\n', metrics.classification_report(y_test,ensemble_boosting.predict(X_test_scaled)))
print('--------------------------------------------------------')
print('Результат StackingClassifier:', '\n', metrics.classification_report(y_test,ensemble_stack.predict(X_test_scaled)))
# Out:
# Результат LogisticRegression:
#                precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84      1906
#            1       0.83      0.81      0.82      1689
#
#     accuracy                           0.83      3595
#    macro avg       0.83      0.83      0.83      3595
# weighted avg       0.83      0.83      0.83      3595
#
# --------------------------------------------------------
# Результат DecisionTreeClassifier:
#                precision    recall  f1-score   support
#
#            0       0.85      0.76      0.81      1906
#            1       0.76      0.85      0.80      1689
#
#     accuracy                           0.80      3595
#    macro avg       0.81      0.81      0.80      3595
# weighted avg       0.81      0.80      0.80      3595
#
# --------------------------------------------------------
# Результат RandomForestClassifier:
#                precision    recall  f1-score   support
#
#            0       0.90      0.80      0.84      1906
#            1       0.80      0.90      0.84      1689
#
#     accuracy                           0.84      3595
#    macro avg       0.85      0.85      0.84      3595
# weighted avg       0.85      0.84      0.84      3595
#
# --------------------------------------------------------
# Результат GradientBoostingClassifier:
#                precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86      1906
#            1       0.82      0.89      0.86      1689
#
#     accuracy                           0.86      3595
#    macro avg       0.86      0.86      0.86      3595
# weighted avg       0.86      0.86      0.86      3595
#
# --------------------------------------------------------
# Результат StackingClassifier:
#                precision    recall  f1-score   support
#
#            0       0.89      0.84      0.86      1906
#            1       0.83      0.88      0.85      1689
#
#     accuracy                           0.86      3595
#    macro avg       0.86      0.86      0.86      3595
# weighted avg       0.86      0.86      0.86      3595
